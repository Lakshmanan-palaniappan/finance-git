# %%
# %pip install -r /Workspace/Users/mathankumardevv@gmail.com/finance-git/requirements.txt

# %%
import os

print(os.getcwd())

# %%
import sys

for path in sys.path:
    print(path)

# %%
from generators.main import main

main()

# %%
# %sql DESCRIBE EXTERNAL LOCATION `storage-connector`;

# %%
# %sql
SHOW GRANTS ON EXTERNAL LOCATION `storage-connector`;

# %%
from generators.main import main

main()
